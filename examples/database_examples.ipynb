# %% [markdown]
# # Database reference

# %%
from scipy.constants import c
import pymwm
wl_max = 10.0
wl_min = 1.0

params = {'core': {'shape': 'cylinder', 'size': 1.0,
                   'fill': {'RI': 1.5}},
          'clad': {'model': 'gold_rakic', 'im_factor': 1.0},
          'bounds': {'wl_max': wl_max, 'wl_min': wl_min,
                     'wl_imag': 100.0},  # conditions for use
          'modes': {'num_n': 6, 'num_m': 2, 'wl_min': 1.0, 'wl_max': 10.0,
                    'wl_imag': 10.0, 'dw': 1.0 / 256}}  # sampling setting for database
wg = pymwm.create(params)  # It takes hours for the first time

# %% [markdown]
# ## Catalog

# %%
database = wg.samples.database
sn = database.get_sn()  # sample data number for the waveguide with params specified above
catalog = database.load_catalog()
catalog.query(f'sn >= {sn}')
# Out:
#         sn     shape  size  size2    core        clad  wl_max  wl_min  \
# 2878  2878  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2879  2879  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2880  2880  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2881  2881  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2882  2882  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2883  2883  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2884  2884  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2885  2885  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2886  2886  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2887  2887  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2888  2888  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2889  2889  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2890  2890  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2891  2891  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2892  2892  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2893  2893  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2894  2894  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2895  2895  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2896  2896  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2897  2897  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2898  2898  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2899  2899  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2900  2900  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2901  2901  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2902  2902  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2903  2903  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2904  2904  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2905  2905  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2906  2906  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2907  2907  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
#
#       wl_imag        dw  num_n  num_m  im_factor EM  n  m
# 2878     10.0  0.003906      6      2        1.0  E  0  1
# 2879     10.0  0.003906      6      2        1.0  E  0  2
# 2880     10.0  0.003906      6      2        1.0  E  1  1
# 2881     10.0  0.003906      6      2        1.0  E  1  2
# 2882     10.0  0.003906      6      2        1.0  E  2  1
# 2883     10.0  0.003906      6      2        1.0  E  2  2
# 2884     10.0  0.003906      6      2        1.0  E  3  1
# 2885     10.0  0.003906      6      2        1.0  E  3  2
# 2886     10.0  0.003906      6      2        1.0  E  4  1
# 2887     10.0  0.003906      6      2        1.0  E  4  2
# 2888     10.0  0.003906      6      2        1.0  E  5  1
# 2889     10.0  0.003906      6      2        1.0  E  5  2
# 2890     10.0  0.003906      6      2        1.0  M  0  1
# 2891     10.0  0.003906      6      2        1.0  M  0  2
# 2892     10.0  0.003906      6      2        1.0  M  0  3
# 2893     10.0  0.003906      6      2        1.0  M  1  1
# 2894     10.0  0.003906      6      2        1.0  M  1  2
# 2895     10.0  0.003906      6      2        1.0  M  1  3
# 2896     10.0  0.003906      6      2        1.0  M  2  1
# 2897     10.0  0.003906      6      2        1.0  M  2  2
# 2898     10.0  0.003906      6      2        1.0  M  2  3
# 2899     10.0  0.003906      6      2        1.0  M  3  1
# 2900     10.0  0.003906      6      2        1.0  M  3  2
# 2901     10.0  0.003906      6      2        1.0  M  3  3
# 2902     10.0  0.003906      6      2        1.0  M  4  1
# 2903     10.0  0.003906      6      2        1.0  M  4  2
# 2904     10.0  0.003906      6      2        1.0  M  4  3
# 2905     10.0  0.003906      6      2        1.0  M  5  1
# 2906     10.0  0.003906      6      2        1.0  M  5  2
# 2907     10.0  0.003906      6      2        1.0  M  5  3

# %% [markdown]
# ## Delete data

# %%
import subprocess
subprocess.call("cp ~/.pymwm/pymwm_data.h5 ~/.pymwm/pymwm_data.h5.bak", shell=True)
sns = catalog.query(f'sn >= {sn}')['sn']
database.delete(sns)
database.load()
catalog = database.load_catalog()
sn = database.get_sn()  # sample data number for the waveguide with params specified above
catalog.query(f'sn >= {sn}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-f222dab34960> in <module>
#       3 sns = catalog.query(f'sn >= {sn}')['sn']
#       4 database.delete(sns)
# ----> 5 database.load()
#       6 catalog = database.load_catalog()
#       7 sn = database.get_sn()  # sample data number for the waveguide with params specified above
#
# ~/usr/lib/PyMWM/pymwm/waveguide.py in load(self)
#     666             #  If there is no data for sn, IndexError should be raised
#     667             #  in the following expression.
# --> 668             indices = [catalog[catalog['sn'] == sn].index[0] for sn in sns]
#     669             for i, sn in zip(indices, sns):
#     670                 em = catalog.loc[i, 'EM']
#
# ~/usr/lib/PyMWM/pymwm/waveguide.py in <listcomp>(.0)
#     666             #  If there is no data for sn, IndexError should be raised
#     667             #  in the following expression.
# --> 668             indices = [catalog[catalog['sn'] == sn].index[0] for sn in sns]
#     669             for i, sn in zip(indices, sns):
#     670                 em = catalog.loc[i, 'EM']
#
# ~/anaconda3/envs/ray/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4295         if is_scalar(key):
#    4296             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4297             return getitem(key)
#    4298
#    4299         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
subprocess.call("mv ~/.pymwm/pymwm_data.h5.bak ~/.pymwm/pymwm_data.h5", shell=True)
database.load()
catalog = database.load_catalog()
sn = database.get_sn()  # sample data number for the waveguide with params specified above
catalog.query(f'sn >= {sn}')
# Out:
#         sn     shape  size  size2    core        clad  wl_max  wl_min  \
# 2878  2878  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2879  2879  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2880  2880  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2881  2881  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2882  2882  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2883  2883  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2884  2884  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2885  2885  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2886  2886  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2887  2887  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2888  2888  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2889  2889  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2890  2890  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2891  2891  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2892  2892  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2893  2893  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2894  2894  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2895  2895  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2896  2896  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2897  2897  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2898  2898  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2899  2899  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2900  2900  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2901  2901  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2902  2902  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2903  2903  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2904  2904  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2905  2905  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2906  2906  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
# 2907  2907  cylinder   1.0    0.0  RI_1.5  gold_rakic    10.0     1.0
#
#       wl_imag        dw  num_n  num_m  im_factor EM  n  m
# 2878     10.0  0.003906      6      2        1.0  E  0  1
# 2879     10.0  0.003906      6      2        1.0  E  0  2
# 2880     10.0  0.003906      6      2        1.0  E  1  1
# 2881     10.0  0.003906      6      2        1.0  E  1  2
# 2882     10.0  0.003906      6      2        1.0  E  2  1
# 2883     10.0  0.003906      6      2        1.0  E  2  2
# 2884     10.0  0.003906      6      2        1.0  E  3  1
# 2885     10.0  0.003906      6      2        1.0  E  3  2
# 2886     10.0  0.003906      6      2        1.0  E  4  1
# 2887     10.0  0.003906      6      2        1.0  E  4  2
# 2888     10.0  0.003906      6      2        1.0  E  5  1
# 2889     10.0  0.003906      6      2        1.0  E  5  2
# 2890     10.0  0.003906      6      2        1.0  M  0  1
# 2891     10.0  0.003906      6      2        1.0  M  0  2
# 2892     10.0  0.003906      6      2        1.0  M  0  3
# 2893     10.0  0.003906      6      2        1.0  M  1  1
# 2894     10.0  0.003906      6      2        1.0  M  1  2
# 2895     10.0  0.003906      6      2        1.0  M  1  3
# 2896     10.0  0.003906      6      2        1.0  M  2  1
# 2897     10.0  0.003906      6      2        1.0  M  2  2
# 2898     10.0  0.003906      6      2        1.0  M  2  3
# 2899     10.0  0.003906      6      2        1.0  M  3  1
# 2900     10.0  0.003906      6      2        1.0  M  3  2
# 2901     10.0  0.003906      6      2        1.0  M  3  3
# 2902     10.0  0.003906      6      2        1.0  M  4  1
# 2903     10.0  0.003906      6      2        1.0  M  4  2
# 2904     10.0  0.003906      6      2        1.0  M  4  3
# 2905     10.0  0.003906      6      2        1.0  M  5  1
# 2906     10.0  0.003906      6      2        1.0  M  5  2
# 2907     10.0  0.003906      6      2        1.0  M  5  3
